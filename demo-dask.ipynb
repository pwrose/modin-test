# %%
import os
import shutil
import gzip
import urllib.request
import modin.pandas as pd
from dask.distributed import Client

# %%
url = "https://ftp.ncbi.nlm.nih.gov/gene/DATA/gene_info.gz"
urllib.request.urlretrieve(url, "gene_info.gz")
# Out:
# ('gene_info.gz', <http.client.HTTPMessage at 0x10ca2b370>)

# %%
def unzip(filename_in, filename_out):
    with gzip.open(filename_in, "rb") as f_in:
        with open(filename_out, "wb") as f_out:
            shutil.copyfileobj(f_in, f_out)

# %%
unzip("gene_info.gz", "gene_info.tsv")

# %%
# !ls -l
# Out:
# total 12838440
# drwxr-xr-x  4 Peter  staff         128 Aug  6 15:22 dask-worker-space
# -rw-r--r--  1 Peter  staff        2690 Aug  6 15:46 demo-dask.ipynb
# -rw-r--r--  1 Peter  staff         106 Aug  6 12:35 environment.yml
# -rw-r--r--  1 Peter  staff   837030191 Aug  6 15:46 gene_info.gz
# -rw-r--r--  1 Peter  staff  5502053729 Aug  6 15:46 gene_info.tsv
# -rw-r--r--  1 Peter  staff       42777 Aug  6 15:23 quickstart-dask.ipynb
# -rw-r--r--  1 Peter  staff   209028075 Aug  6 15:20 taxi.csv

# %%
client = Client()

# %%
df = pd.read_csv("gene_info.tsv", dtype=str, sep="\t")
# Out:
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Worker exceeded 95% memory budget. Restarting
# distributed.nanny - WARNING - Restarting worker
# ...

# %%
client.close()
# Out:
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 2.80 GiB -- Worker memory limit: 4.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 2.83 GiB -- Worker memory limit: 4.00 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 2.82 GiB -- Worker memory limit: 4.00 GiB
# ...
